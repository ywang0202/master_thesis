# %% [markdown]
# # Required Libraries + Load in Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#Load in dataset services 2019-2022 (0.1s)
dis19 = pd.read_csv("Train Disruptions 2019-2025/disruptions-2019.csv")
dis20 = pd.read_csv("Train Disruptions 2019-2025/disruptions-2020.csv")
dis21 = pd.read_csv("Train Disruptions 2019-2025/disruptions-2021.csv")
dis22 = pd.read_csv("Train Disruptions 2019-2025/disruptions-2022.csv")

# %%
#Load in dataset services 2023-2025 (0.0s)
dis23 = pd.read_csv("Train Disruptions 2019-2025/disruptions-2023.csv")
dis24 = pd.read_csv("Train Disruptions 2019-2025/disruptions-2024.csv")
dis25 = pd.read_csv("Train Disruptions 2019-2025/disruptions-2025.csv")

# %%
#Concatenate dataset disruption as one (0.1s)

train_disruption = pd.concat([dis19, dis20, dis21, dis22, dis23, dis24, dis25], ignore_index= True)
col_names = train_disruption.columns
print( f" The column names of disruptions are: {col_names}" )

rows, columns = train_disruption.shape
print( f"train_disruption has Rows: {rows}, Columns: {columns}")
# Out:
#  The column names of disruptions are: Index(['rdt_id', 'ns_lines', 'rdt_lines', 'rdt_lines_id', 'rdt_station_names',
#        'rdt_station_codes', 'cause_nl', 'cause_en', 'statistical_cause_nl',
#        'statistical_cause_en', 'cause_group', 'start_time', 'end_time',
#        'duration_minutes'],
#       dtype='str')
# train_disruption has Rows: 38571, Columns: 14

# %% [markdown]
# # Analyzing the Data

# %%
# Check for duplicates 
train_disruption.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Display basic information about the DataFrame: 
# number of rows, columns, data types, and non-null counts

train_disruption.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38571 entries, 0 to 38570
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rdt_id                38571 non-null  int64
#  1   ns_lines              38571 non-null  str
#  2   rdt_lines             38559 non-null  str
#  3   rdt_lines_id          38559 non-null  str
#  4   rdt_station_names     38563 non-null  str
#  5   rdt_station_codes     38563 non-null  str
#  6   cause_nl              38571 non-null  str
#  7   cause_en              38571 non-null  str
#  8   statistical_cause_nl  38571 non-null  str
#  9   statistical_cause_en  38571 non-null  str
#  10  cause_group           38569 non-null  str
#  11  start_time            38571 non-null  str
#  12  end_time              38461 non-null  str
#  13  duration_minutes      38460 non-null  float64
# dtypes: float64(1), int64(1), str(12)
# memory usage: 4.1 MB

# %%
# Display summary statistics for numerical columns
train_disruption.describe()
# Out:
#              rdt_id  duration_minutes
# count  38571.000000      38460.000000
# mean   44571.139224        162.620281
# std    11193.096194        859.044243
# min    25236.000000          0.000000
# 25%    34878.500000         18.000000
# 50%    44521.000000         47.000000
# 75%    54316.500000        131.000000
# max    63959.000000      45302.000000

# %%
# Display summary for categorical columns
train_disruption.describe(include=["object", "string", "category"])
# Out:
#                      ns_lines                         rdt_lines rdt_lines_id  \
# count                   38571                             38559        38559
# unique                   1517                               518          518
# top     Rotterdam-Breda (HSL)  Breda - Rotterdam Centraal (HSL)           15
# freq                     1090                              1385         1385
#
#                rdt_station_names rdt_station_codes       cause_nl  \
# count                      38563             38563          38571
# unique                      1951              1951             95
# top     Breda,Rotterdam Centraal           BD, RTD  defecte trein
# freq                        1385              1385          13566
#
#                  cause_en statistical_cause_nl statistical_cause_en  \
# count               38571                38571                38571
# unique                 91                   95                   91
# top     broken down train        defecte trein    broken down train
# freq                13566                13600                13600
#
#           cause_group           start_time             end_time
# count           38569                38571                38461
# unique              9                38523                38410
# top     rolling stock  2019-01-08 17:56:08  2021-01-25 19:45:00
# freq            16478                    2                    3

# %%
# Check if cause_en and statistical_cause_en columns are equal
train_disruption['cause_en'].equals(train_disruption['statistical_cause_en'])
# Out:
# False

# %%
# Check for values in 'cause_en' and 'statistical_cause_en' columns that are not the same
train_disruption.loc[train_disruption[['cause_en','statistical_cause_en']].nunique(1)>1]
# Out:
#        rdt_id                                           ns_lines  \
# 90      25326                           Utrecht-'s-Hertogenbosch
# 102     25338                                    Nijmegen-Venray
# 121     25357                 Amsterdam-Schiphol-Rotterdam (HSL)
# 284     25520                                  Nijmegen-Roermond
# 468     25704                                   Schiphol Airport
# ...       ...                                                ...
# 37607   62996                               Heerlen - Maastricht
# 37655   63044                                 Amsterdam Centraal
# 37977   63366  Groningen - Bad Nieuweschans; Groningen - Veendam
# 38507   63896                                 Amsterdam Centraal
# 38533   63922                               Heerlen - Aachen Hbf
#
#                                                rdt_lines  \
# 90     's-Hertogenbosch - Utrecht Centraal, Tiel - Ut...
# 102                                     Nijmegen - Venlo
# 121    Amsterdam Centraal - Schiphol Airport, Rotterd...
# 284                                     Nijmegen - Venlo
# 468    Amersfoort - Schiphol Airport, Amsterdam Centr...
# ...                                                  ...
# 37607                               Heerlen - Maastricht
# 37655  Alkmaar - Amsterdam Centraal, Amersfoort - Ams...
# 37977  Groningen - Bad Nieuweschans, Groningen - Leer...
# 38507  Alkmaar - Amsterdam Centraal, Amersfoort - Ams...
# 38533                               Aachen Hbf - Heerlen
#
#                          rdt_lines_id  \
# 90                            150,151
# 102                                64
# 121                             24,32
# 284                                64
# 468          22,24,32,137,144,148,165
# ...                               ...
# 37607                              76
# 37655  32,112,135,136,141,145,161,164
# 37977                     154,155,156
# 38507  32,112,135,136,141,145,161,164
# 38533                             130
#
#                                        rdt_station_names  \
# 90     Houten,Houten Castellum,Utrecht Centraal,Utrec...
# 102    Boxmeer,Cuijk,Mook-Molenhoek,Nijmegen,Nijmegen...
# 121    Amsterdam Centraal,Amsterdam Lelylaan,Amsterda...
# 284    Boxmeer,Cuijk,Mook-Molenhoek,Nijmegen,Nijmegen...
# 468                                     Schiphol Airport
# ...                                                  ...
# 37607  Heerlen,Heerlen Woonboulevard,Klimmen-Ransdaal...
# 37655                  Amsterdam Centraal,Twello,Kontich
# 37977  Groningen Europapark,Groningen,Hoogezand-Sappe...
# 38507                  Amsterdam Centraal,Twello,Kontich
# 38533  Aachen Hbf,Eygelshoven Markt,Heerlen,Herzogenr...
#
#                                      rdt_station_codes            cause_nl  \
# 90                           HTN, HTNC, UT, UTLN, UTVR  eerdere verstoring
# 102                   BMR, CK, MMLH, NM, NMH, VLB, VRY  eerdere verstoring
# 121                           ASD, ASDL, ASS, RTD, SHL  eerdere verstoring
# 284                   BMR, CK, MMLH, NM, NMH, VLB, VRY  eerdere verstoring
# 468                                                SHL  eerdere verstoring
# ...                                                ...                 ...
# 37607  HRL, HRLW, KMR, MES, MT, SGL, SOG, VDL, VK, MTN  eerdere verstoring
# 37655                                    ASD, TWL, FKI  eerdere verstoring
# 37977                       GERP, GN, HGZ, KW, MTH, ZB  eerdere verstoring
# 38507                                    ASD, TWL, FKI  eerdere verstoring
# 38533                      AHBF, EGHM, HRL, HZ, LG, AW  eerdere verstoring
#
#                     cause_en              statistical_cause_nl  \
# 90     an earlier disruption                   gestrande trein
# 102    an earlier disruption                     defecte trein
# 121    an earlier disruption                 verstoring elders
# 284    an earlier disruption                     defecte trein
# 468    an earlier disruption            inzet van de brandweer
# ...                      ...                               ...
# 37607  an earlier disruption  problemen met de personeelsinzet
# 37655  an earlier disruption              persoon op het spoor
# 37977  an earlier disruption                     defecte trein
# 38507  an earlier disruption              persoon op het spoor
# 38533  an earlier disruption          rijp aan de bovenleiding
#
#                     statistical_cause_en    cause_group           start_time  \
# 90                        stranded train  rolling stock  2019-01-07 17:57:09
# 102                    broken down train  rolling stock  2019-01-08 08:54:11
# 121                 disruption elsewhere     logistical  2019-01-08 18:56:19
# 284                    broken down train  rolling stock  2019-01-18 12:15:03
# 468    deployment of the fire department       external  2019-01-25 18:06:18
# ...                                  ...            ...                  ...
# 37607                  staffing problems          staff  2025-11-07 09:30:53
# 37655        person on the railway track       external  2025-11-10 18:48:49
# 37977                  broken down train  rolling stock  2025-11-25 12:22:06
# 38507        person on the railway track       external  2025-12-27 21:49:29
# 38533  overhead wires covered with frost        weather  2025-12-30 07:22:49
#
#                   end_time  duration_minutes
# 90     2019-01-07 19:58:12             121.0
# 102    2019-01-08 12:51:10             237.0
# 121    2019-01-09 02:11:02             435.0
# 284    2019-01-18 15:02:05             167.0
# 468    2019-01-25 19:32:17              86.0
# ...                    ...               ...
# 37607  2025-11-07 11:44:18             133.0
# 37655  2025-11-10 20:31:23             103.0
# 37977  2025-11-25 15:25:07             183.0
# 38507  2025-12-27 22:36:17              47.0
# 38533  2025-12-30 13:01:22             339.0
#
# [190 rows x 14 columns]

# %%
# Remove the following columns
train_disruption = train_disruption.drop(['cause_nl', 'cause_en', 'statistical_cause_nl'], axis=1)

# %%
#Check if drop columns was successful 
train_disruption.columns.values
# Out:
# <StringArray>
# [              'rdt_id',             'ns_lines',            'rdt_lines',
#          'rdt_lines_id',    'rdt_station_names',    'rdt_station_codes',
#  'statistical_cause_en',          'cause_group',           'start_time',
#              'end_time',     'duration_minutes']
# Length: 11, dtype: str

# %% [markdown]
# # Dealing with Missing Values

# %%
# Check for missing values in each column and calculate the percentage of missing values
total = train_disruption.isnull().sum().sort_values(ascending=False)
percent = (train_disruption.isnull().sum()/train_disruption.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                       Total   Percent
# duration_minutes        111  0.002878
# end_time                110  0.002852
# rdt_lines                12  0.000311
# rdt_lines_id             12  0.000311
# rdt_station_names         8  0.000207
# rdt_station_codes         8  0.000207
# cause_group               2  0.000052
# ns_lines                  0  0.000000
# rdt_id                    0  0.000000
# statistical_cause_en      0  0.000000
# start_time                0  0.000000

# %%
# Display rows with missing values
null_data = train_disruption[train_disruption.isnull().any(axis=1)]
null_data
# Out:
#        rdt_id                                ns_lines  \
# 629     25865           Amsterdam-Brussel-Paris (HSL)
# 681     25917                           Alkmaar-Hoorn
# 3080    28316  Hoofddorp-Schiphol-Almere Oostvaarders
# 4072    29308                        Zwolle-Groningen
# 4479    29715                Amsterdam-Köln-Frankfurt
# ...       ...                                     ...
# 30742   56131                     Amersfoort - Zwolle
# 31443   56832                       Amsterdam - Gouda
# 34490   59879  Deventer - Enschede; Zwolle - Enschede
# 34824   60213              's-Hertogenbosch - Tilburg
# 35907   61296  Lelystad Centrum - Rotterdam - Brussel
#
#                                                rdt_lines rdt_lines_id  \
# 629                                                  NaN          NaN
# 681                                                  NaN          NaN
# 3080                                                 NaN          NaN
# 4072                                  Groningen - Zwolle          146
# 4479                  Arnhem Centraal - Utrecht Centraal          133
# ...                                                  ...          ...
# 30742                                Amersfoort - Zwolle           48
# 31443  Amsterdam Centraal - Utrecht Centraal, Amsterd...      136,141
# 34490                                   Almelo - Hengelo           89
# 34824                         's-Hertogenbosch - Tilburg           69
# 35907                                                NaN          NaN
#
#                                        rdt_station_names  \
# 629                                                  NaN
# 681                                                Hoorn
# 3080                                           Hoofddorp
# 4072                Assen,Beilen,Hoogeveen,Meppel,Zwolle
# 4479   Arnhem Centraal,Bunnik,Driebergen-Zeist,Ede-Wa...
# ...                                                  ...
# 30742  Amersfoort Centraal,Amersfoort Schothorst,Amer...
# 31443  Abcoude,Amsterdam Amstel,Amsterdam Bijlmer Are...
# 34490                Almelo,Almelo de Riet,Borne,Hengelo
# 34824                           's-Hertogenbosch,Tilburg
# 35907  Abcoude,Almere Centrum,Almere Buiten,Almere Mu...
#
#                                        rdt_station_codes  \
# 629                                                  NaN
# 681                                                   HN
# 3080                                                 HFD
# 4072                                ASN, BL, HGV, MP, ZL
# 4479        AH, BNK, DB, ED, KLP, MRN, OTB, UT, WF, UTVR
# ...                                                  ...
# 30742  AMF, AMFS, AVAT, EML, HD, HDE, NKK, NS, PT, WZ...
# 31443            AC, ASA, ASB, ASD, ASDM, ASHD, BKL, DVD
# 34490                                 AML, AMRI, BN, HGL
# 34824                                             HT, TB
# 35907  AC, ALM, ALMB, ALMM, ALMO, ALMP, ASB, ASHD, BK...
#
#                statistical_cause_en     cause_group           start_time  \
# 629            disruption elsewhere      logistical  2019-02-03 22:06:26
# 681               broken down train   rolling stock  2019-02-06 16:41:05
# 3080              broken down train   rolling stock  2019-07-04 19:58:18
# 4072              broken down train   rolling stock  2019-09-04 20:24:37
# 4479          person hit by a train       accidents  2019-10-02 07:13:40
# ...                             ...             ...                  ...
# 30742                 police action        external  2024-10-24 21:21:23
# 31443  deployment of security staff             NaN  2024-12-01 19:34:39
# 34490                signal failure  infrastructure  2025-05-15 09:54:45
# 34824                     collision       accidents  2025-06-04 19:14:28
# 35907          an amended timetable         weather  2025-08-04 08:12:15
#
#                   end_time  duration_minutes
# 629    2019-02-03 22:08:03               2.0
# 681    2019-02-06 16:50:47              10.0
# 3080   2019-07-04 19:59:03               1.0
# 4072                   NaN               NaN
# 4479                   NaN               NaN
# ...                    ...               ...
# 30742                  NaN               NaN
# 31443  2024-12-01 20:09:45              35.0
# 34490                  NaN               NaN
# 34824                  NaN               NaN
# 35907  2025-08-04 22:02:11             830.0
#
# [125 rows x 11 columns]

# %%
# Make a list of numerical and categorical columns
num_cols = train_disruption.select_dtypes(include=np.number).columns  # rdt_id and duration_minutes
cat_cols = train_disruption.select_dtypes(exclude=np.number).columns

# Drop whole row if start_time or end_time is missing
# and duration_minutes is also missing, or if duration_minutes is missing
drop_rows = (
    ((train_disruption["start_time"].isna() | train_disruption["end_time"].isna())
    & train_disruption["duration_minutes"].isna())
    | train_disruption["duration_minutes"].isna()
)
train_disruption = train_disruption.loc[~drop_rows].copy()

# Fill specific categorical columns with 'Unknown'
cols_to_fill = ["rdt_lines", "rdt_lines_id", "rdt_station_names", "rdt_station_codes", "cause_group"]

for col in cols_to_fill:
    train_disruption[col] = train_disruption[col].fillna("Unknown")

# %% [markdown]
# # Dealing with outliers (duration_minutes)

# %% [markdown]
# ## General Univariate Analysis for duration_minutes

# %%
# General Univariate analysis for duration_minutes
duration = train_disruption["duration_minutes"].dropna()

# Categorize duration into groups
bins = [0, 15, 30, 60, 120, np.inf]
labels = ["0–15 min", "16–30 min", "31–60 min", "61–120 min", "120+ min"]

duration_bins = pd.cut(
    train_disruption["duration_minutes"],
    bins=bins,
    labels=labels,
    include_lowest=True
)

# Counts per category
duration_counts = duration_bins.value_counts().sort_index()
display(duration_counts)

# Pie chart: Check the distribution of duration_minutes
plt.figure(figsize=(6, 6))
plt.pie(duration_counts, labels=duration_counts.index, autopct="%1.1f%%", startangle=90)
plt.title("Duration Categories")
plt.show()

# Boxplot: Check the distribution of duration_minutes
plt.figure(figsize=(6, 2))
sns.boxplot(x=train_disruption['duration_minutes'])
plt.title("Boxplot of Duration in Minutes (duration_minutes)")
plt.show()
# Out:
# duration_minutes
# 0–15 min       8573
# 16–30 min      5908
# 31–60 min      7214
# 61–120 min     6336
# 120+ min      10429
# Name: count, dtype: int64

# %%
# Summary statistics
display(train_disruption['duration_minutes'].describe())
# Out:
# count    38460.000000
# mean       162.620281
# std        859.044243
# min          0.000000
# 25%         18.000000
# 50%         47.000000
# 75%        131.000000
# max      45302.000000
# Name: duration_minutes, dtype: float64

# %%
# Identify outliers in duration_minutes using the Interquartile Range (IQR) method
# https://www.geeksforgeeks.org/pandas/handling-outliers-with-pandas/ 

Q1 = train_disruption['duration_minutes'].quantile(0.25) #18 minutes
Q3 = train_disruption['duration_minutes'].quantile(0.75) #131 minutes
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove legacy category column from previous runs (if present)
train_disruption = train_disruption.drop(columns=["duration_category"], errors="ignore")

outliers = train_disruption[(train_disruption['duration_minutes'] < lower_bound) | (train_disruption['duration_minutes'] > upper_bound)]
display(outliers)

# 38571 rows, 11 columns, and 3427 rows of outliers in duration_minutes column. 8.88% of the data are outliers.
# 1 day = 1440 minutes
# Out:
#        rdt_id                                ns_lines  \
# 35      25271                        Zwolle-Groningen
# 69      25305                       Hengelo-Bielefeld
# 89      25325            Hoofddorp-Schiphol-Hilversum
# 97      25333       Alkmaar-Den Helder; Alkmaar-Hoorn
# 110     25346                   Rotterdam-Breda (HSL)
# ...       ...                                     ...
# 38524   63913  Amsterdam - Utrecht; Amsterdam - Gouda
# 38531   63920                  Amersfoort - Barneveld
# 38533   63922                    Heerlen - Aachen Hbf
# 38550   63939           Maastricht - Heerlen - Aachen
# 38551   63940               Maastricht - Liège / Luik
#
#                                                rdt_lines    rdt_lines_id  \
# 35                                    Groningen - Zwolle             146
# 69     Berlin Ostbahnhof - Hengelo, Bielefeld Hbf - H...      91,124,174
# 89     Amersfoort - Schiphol Airport, Leiden Centraal...  22,137,144,148
# 97                 Alkmaar - Den Helder, Alkmaar - Hoorn         162,163
# 110                     Breda - Rotterdam Centraal (HSL)              15
# ...                                                  ...             ...
# 38524  Amsterdam Centraal - Utrecht Centraal, Amsterd...         136,141
# 38531                        Amersfoort - Ede-Wageningen              47
# 38533                               Aachen Hbf - Heerlen             130
# 38550         Aachen Hbf - Heerlen, Heerlen - Maastricht          76,130
# 38551  Liège-Guillemins - Maastricht, Maastricht - Ma...          75,121
#
#                                        rdt_station_names  \
# 35                                      Hoogeveen,Meppel
# 69           Bad Bentheim,Hengelo,Hengelo Oost,Oldenzaal
# 89             Amsterdam Zuid,Hoofddorp,Schiphol Airport
# 97                   Alkmaar,Alkmaar Noord,Heerhugowaard
# 110                             Breda,Rotterdam Centraal
# ...                                                  ...
# 38524  Amsterdam Amstel,Amsterdam Bijlmer ArenA,Amste...
# 38531  Amersfoort Centraal,Barneveld Centrum,Barnevel...
# 38533  Aachen Hbf,Eygelshoven Markt,Heerlen,Herzogenr...
# 38550  Aachen Hbf,Eygelshoven Markt,Heerlen,Heerlen W...
# 38551  Bressoux,Eijsden,Visé,Liège-Guillemins,Maastri...
#
#                                        rdt_station_codes  \
# 35                                               HGV, MP
# 69                                    BH, HGL, HGLO, ODZ
# 89                                        ASDZ, HFD, SHL
# 97                                        AMR, AMRN, HWD
# 110                                              BD, RTD
# ...                                                  ...
# 38524                           ASA, ASB, ASD, ASDM, DVD
# 38531                            AMF, BNC, BNN, HVL, BNZ
# 38533                        AHBF, EGHM, HRL, HZ, LG, AW
# 38550  AHBF, EGHM, HRL, HRLW, HZ, KMR, LG, MES, MT, S...
# 38551                    BRESSX, EDN, FVS, LUIK, MT, MTR
#
#                       statistical_cause_en     cause_group  \
# 35                       broken down train   rolling stock
# 69         problems with the rolling stock   rolling stock
# 89                          points failure  infrastructure
# 97                   person hit by a train       accidents
# 110                         points failure  infrastructure
# ...                                    ...             ...
# 38524               damaged overhead wires  infrastructure
# 38531      problems with the rolling stock   rolling stock
# 38533    overhead wires covered with frost         weather
# 38550  ice formation on the overhead wires         weather
# 38551  ice formation on the overhead wires         weather
#
#                 start_time             end_time  duration_minutes
# 35     2019-01-04 04:56:09  2019-01-05 22:47:07            2511.0
# 69     2019-01-06 08:25:05  2019-01-06 21:49:09             804.0
# 89     2019-01-07 14:20:47  2019-01-07 20:59:41             399.0
# 97     2019-01-07 23:49:33  2019-01-08 07:18:42             449.0
# 110    2019-01-08 15:08:31  2019-01-08 20:27:42             319.0
# ...                    ...                  ...               ...
# 38524  2025-12-29 14:08:11  2025-12-30 00:34:19             626.0
# 38531  2025-12-30 04:25:09  2025-12-30 20:45:56             981.0
# 38533  2025-12-30 07:22:49  2025-12-30 13:01:22             339.0
# 38550  2025-12-31 03:39:10  2025-12-31 08:56:59             318.0
# 38551  2025-12-31 03:42:54  2025-12-31 09:12:05             329.0
#
# [3427 rows x 11 columns]

# %%
outliers.sort_values(by='duration_minutes', ascending=False).head(10)
# Out:
#        rdt_id                           ns_lines  \
# 18389   43625                   Roermond-Sittard
# 15286   40522                  Hengelo-Bielefeld
# 21762   46998                Leeuwarden-Stavoren
# 21272   46508                         Leeuwarden
# 21273   46509                          Groningen
# 21276   46512               Groningen-Leeuwarden
# 33843   59232          Maastricht - Liège / Luik
# 31471   56860               Heerlen - Maastricht
# 31832   57221      Maastricht - Heerlen - Aachen
# 15199   40435  Amsterdam-Rotterdam-Brussel (HSL)
#
#                                                rdt_lines  \
# 18389                                 Roermond - Sittard
# 15286  Berlin Ostbahnhof - Hengelo, Bielefeld Hbf - H...
# 21762                              Leeuwarden - Stavoren
# 21272  Groningen - Leeuwarden, Harlingen Haven - Leeu...
# 21273  Delfzijl - Groningen, Groningen - Bad Nieuwesc...
# 21276                             Groningen - Leeuwarden
# 33843  Liège-Guillemins - Maastricht, Maastricht - Ma...
# 31471                               Heerlen - Maastricht
# 31832                               Heerlen - Maastricht
# 15199  Amsterdam Centraal - Schiphol Airport, Brussel...
#
#                       rdt_lines_id  \
# 18389                           73
# 15286                   91,124,174
# 21762                          104
# 21272              102,103,104,160
# 21273  102,146,154,155,156,157,158
# 21276                          102
# 33843                       75,121
# 31471                           76
# 31832                           76
# 15199                24,32,123,167
#
#                                        rdt_station_names  \
# 18389                     Echt,Roermond,Susteren,Sittard
# 15286        Bad Bentheim,Hengelo,Hengelo Oost,Oldenzaal
# 21762  Hindeloopen,IJlst,Koudum-Molkwerum,Sneek,Stavo...
# 21272                                         Leeuwarden
# 21273                                          Groningen
# 21276  Buitenpost,Grijpskerk,Groningen,Hurdegaryp,Lee...
# 33843  Bressoux,Eijsden,Visé,Liège-Guillemins,Maastri...
# 31471  Heerlen,Heerlen Woonboulevard,Klimmen-Ransdaal...
# 31832  Heerlen,Heerlen Woonboulevard,Klimmen-Ransdaal...
# 15199  Amsterdam Centraal,Amsterdam Lelylaan,Amsterda...
#
#                                        rdt_station_codes  \
# 18389                                   EC, RM, SRN, STD
# 15286                                 BH, HGL, HGLO, ODZ
# 21762                         HNP, IJT, KMW, SK, STV, WK
# 21272                                                 LW
# 21273                                                 GN
# 21276             BP, GK, GN, HDG, LW, LWC, ZH, DWE, FWD
# 33843                    BRESSX, EDN, FVS, LUIK, MT, MTR
# 31471    HRL, HRLW, KMR, MES, MT, SGL, SOG, VDL, VK, MTN
# 31832    HRL, HRLW, KMR, MES, MT, SGL, SOG, VDL, VK, MTN
# 15199  ASD, ASDL, ASS, ATW, BRUSC, BRUSN, BRUSZ, MECH...
#
#                   statistical_cause_en       cause_group           start_time  \
# 18389           damaged railway bridge         accidents  2022-07-16 05:29:58
# 15286  problems with the rolling stock     rolling stock  2022-01-03 09:07:30
# 21762                     repair works  engineering work  2023-03-13 16:04:47
# 21272           strike of Arriva staff             staff  2023-02-08 04:48:23
# 21273           strike of Arriva staff             staff  2023-02-08 04:48:27
# 21276           strike of Arriva staff             staff  2023-02-08 07:29:20
# 33843             staff strikes abroad             staff  2025-04-08 05:18:14
# 31471  problems with the rolling stock     rolling stock  2024-12-03 10:15:01
# 31832  problems with the rolling stock     rolling stock  2024-12-27 07:45:33
# 15199                     large crowds          external  2021-12-28 10:33:56
#
#                   end_time  duration_minutes
# 18389  2022-08-16 16:31:29           45302.0
# 15286  2022-02-02 22:43:56           44016.0
# 21762  2023-04-11 10:04:04           41339.0
# 21272  2023-03-08 01:07:41           40099.0
# 21273  2023-03-08 01:07:28           40099.0
# 21276  2023-03-07 07:22:52           38874.0
# 33843  2025-04-29 23:49:11           31351.0
# 31471  2024-12-25 00:15:23           31080.0
# 31832  2025-01-16 00:02:17           28337.0
# 15199  2022-01-16 21:59:29           28046.0

# %%
train_disruption[['statistical_cause_en']].value_counts()
# Out:
# statistical_cause_en
# broken down train               13569
# collision                        3064
# signal failure                   2579
# stranded train                   2288
# points failure                   2058
#                                 ...
# emergency repairs                   2
# fire in a train                     1
# the construction of a tunnel        1
# pilgrimage                          1
# snow                                1
# Name: count, Length: 91, dtype: int64

# %%
# Top 15 causes in outliers
outliers_top15 = outliers["statistical_cause_en"].value_counts().head(15)

# Count those same causes in full dataset (train_disruption)
train_disruption_for_outlier_top15 = (
    train_disruption["statistical_cause_en"]
    .value_counts()
    .reindex(outliers_top15.index, fill_value=0)
)

# Percentage of outliers relative to full dataset for the same cause
outlier_percentage = (
    outliers_top15.div(train_disruption_for_outlier_top15.replace(0, np.nan)) * 100
).round(2)

# Show side by side
pd.DataFrame({
    "outliers_top15": outliers_top15,
    "cause_total": train_disruption_for_outlier_top15,
    "percentage": outlier_percentage
})
# Out:
#                                  outliers_top15  cause_total  percentage
# statistical_cause_en
# staffing problems                           399          570       70.00
# problems with the rolling stock             364          568       64.08
# damaged overhead wires                      297          839       35.40
# signal failure                              277         2579       10.74
# defective railway track                     201          597       33.67
# logistical limitations                      194          451       43.02
# points failure                              187         2058        9.09
# repair works                                182          741       24.56
# strike                                      112          133       84.21
# collision                                    90         3064        2.94
# strike of Arriva staff                       76           85       89.41
# railway problems abroad                      75          295       25.42
# signalling and points failure                73          609       11.99
# broken down train                            72        13569        0.53
# staking bij NS                               69           71       97.18

# %% [markdown]
# ## Outlier Univariate Analysis for duration_minutes

# %%
# Univariate analysis for outliers duration_minutes
duration = outliers["duration_minutes"].dropna()

# Categorize outliers into groups (all outliers are above upper_bound ~264 min)
bins = [240, 480, 720, 1440, np.inf] #bins 0-240 was removed because all outliers are above 240 minutes
labels = ["241–480 min", "481–720 min", "721–1440 min", "1440+ min"]

outlier_duration_bins = pd.cut(
    outliers["duration_minutes"],
    bins=bins,
    labels=labels,
    include_lowest=True
)

# Counts per category
duration_counts = outlier_duration_bins.value_counts().sort_index()
display(duration_counts)

# Pie chart
plt.figure(figsize=(6, 6))
plt.pie(duration_counts, labels=duration_counts.index, autopct="%1.1f%%", startangle=90)
plt.title("Outlier Duration Categories")
plt.show()
# Out:
# duration_minutes
# 241–480 min     1338
# 481–720 min      774
# 721–1440 min     936
# 1440+ min        379
# Name: count, dtype: int64

# %%
outliers_720 = train_disruption["duration_minutes"] > 720
count_over_720 = outliers_720.sum()
total_rows = len(train_disruption)
pct_over_720 = (count_over_720 / total_rows) * 100 if total_rows else 0

print(f"Rows with duration_minutes that are more than 720 min: {count_over_720}, which is {pct_over_720:.2f}% of the dataset ({total_rows} rows)")
# Out:
# Rows with duration_minutes > 720: 1315, which is 3.42% of the dataset (38460 rows).

# %%
drop_rows = train_disruption["duration_minutes"] > 720
train_disruption = train_disruption.loc[~drop_rows].copy()

# %%
train_disruption["duration_minutes"].describe()
# Out:
# count    37145.000000
# mean        89.007538
# std        114.128517
# min          0.000000
# 25%         17.000000
# 50%         44.000000
# 75%        118.000000
# max        720.000000
# Name: duration_minutes, dtype: float64

# %% [markdown]
# # Analysis different years

# %%
# Histogram of total disruptions per year (2019-2025)
yearly_disruptions = pd.Series({
    "2019": len(dis19),
    "2020": len(dis20),
    "2021": len(dis21),
    "2022": len(dis22),
    "2023": len(dis23),
    "2024": len(dis24),
    "2025": len(dis25),
})

plt.figure(figsize=(10, 5))
sns.barplot(x=yearly_disruptions.index, y=yearly_disruptions.values, color="steelblue")
plt.title("Total Number of Disruptions per Year")
plt.xlabel("Year")
plt.ylabel("Number of Disruptions")

# Show exact counts on top of bars
for i, v in enumerate(yearly_disruptions.values):
    plt.text(i, v, f"{v:,}", ha="center", va="bottom")

plt.tight_layout()
plt.show()

# %%
# Top 10 disruption causes for each year (2019-2025)
yearly_data = {
    "2019": dis19,
    "2020": dis20,
    "2021": dis21,
    "2022": dis22,
    "2023": dis23,
    "2024": dis24,
    "2025": dis25,
}

def cause_group_yearly(df):
    for col in ["cause_group"]:
        if col in df.columns:
            return col

top10_cause_yearly = {}

for year, df in yearly_data.items():
    cause_col = cause_group_yearly(df)
    top10_cause_yearly[year] = (
        df[cause_col]
        .fillna("Unknown")
        .value_counts()
        .head(10)
    )

top10_causes_table = pd.concat(top10_cause_yearly, axis=1).fillna(0).astype(int)
top10_causes_table
# Out:
#                   2019  2020  2021  2022  2023  2024  2025
# cause_group
# rolling stock     2967  2044  2176  2108  1923  2309  2951
# infrastructure    1383   979  1090  1176  1177  1394  1576
# accidents          588   529   515   632   539   580   443
# external           506   445   567   781   631   804   866
# logistical         218   232   255   245   232   187   135
# engineering work   175   155   176   228   202   142   149
# weather             61    45    66    45    58    26    51
# unknown             25    21    16    38    77   252   304
# staff               17     0    13   246   329   268   201
# Unknown              0     0     0     0     0     2     0

# %%
# Top 10 statistical causes for each year (2019-2025)
yearly_data = {
    "2019": dis19,
    "2020": dis20,
    "2021": dis21,
    "2022": dis22,
    "2023": dis23,
    "2024": dis24,
    "2025": dis25,
}

def statistical_cause_yearly(df):
    for col in ["statistical_cause_en"]:
        if col in df.columns:
            return col

top10_statistical_cause = {}

for year, df in yearly_data.items():
    cause_col = statistical_cause_yearly(df)
    top10_statistical_cause[year] = (
        df[cause_col]
        .fillna("Unknown")
        .value_counts()
        .head(10)
    )

top10_statistical_causes_table = pd.concat(top10_statistical_cause, axis=1).fillna(0).astype(int)
top10_statistical_causes_table
# Out:
#                                2019  2020  2021  2022  2023  2024  2025
# statistical_cause_en
# broken down train              2326  1618  1758  1707  1705  2062  2424
# stranded train                  535   381   367   295   134   180   399
# signal failure                  435   354   316   358   163   452   511
# points failure                  343   231   333   265   231   286   379
# person hit by a train           320     0     0     0     0     0     0
# an emergency call               181   134   223   358   152   208   180
# disruption elsewhere            141     0     0     0     0     0     0
# collision                       138   488   472   565   495   515   404
# damaged overhead wires          136   120     0   156     0   129     0
# damaged railway bridge          126     0   104     0     0     0   129
# logistical limitations            0   116   106   123     0     0     0
# repair works                      0    92   120   141   146     0     0
# person on the railway track       0    91   107   150   146   207   222
# signalling and points failure     0     0     0     0   289     0     0
# staffing problems                 0     0     0     0   160   173     0
# technical investigation           0     0     0     0     0   246   302
# defective railway track           0     0     0     0     0     0   141
