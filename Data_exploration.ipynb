# %% [markdown]
# # Packages and libraries

# %%
import pandas as pd
import seaborn as sns
import csv 
import os

# %% [markdown]
# # Data Preparation
#
# Changing the 3 datasets ready: Disruptions, Services and weather

# %% [markdown]
# ## Data preparation: Disruptions

# %%
# For train disruptions Dataset Checking if all the column names are the same, to Concatenate them together

df19 = pd.read_csv("Datasets/disruptions-2019.csv")
df20 = pd.read_csv("Datasets/disruptions-2020.csv")
df21 = pd.read_csv("Datasets/disruptions-2021.csv")
df22 = pd.read_csv("Datasets/disruptions-2022.csv")
df23 = pd.read_csv("Datasets/disruptions-2023.csv")
df24 = pd.read_csv("Datasets/disruptions-2024.csv")
df25 = pd.read_csv("Datasets/disruptions-2025.csv")

# rows, columns = df19.shape
# print(f"df19 has Rows: {rows}, Columns: {columns}") df19 has Rows: 5940, Columns: 14
# rows, columns = df20.shape
# print(f"df20 has Rows: {rows}, Columns: {columns}") df20 has Rows: 4450, Columns: 14
# rows, columns = df21.shape
# print(f"df21 has Rows: {rows}, Columns: {columns}") df21 has Rows: 4874, Columns: 14
# rows, columns = df22.shape
# print(f"df22 has Rows: {rows}, Columns: {columns}") df22 has Rows: 5499, Columns: 14
# rows, columns = df23.shape
# print(f"df23 has Rows: {rows}, Columns: {columns}") df23 has Rows: 5168, Columns: 14
# rows, columns = df24.shape
# print(f"df24 has Rows: {rows}, Columns: {columns}") df24 has Rows: 5964, Columns: 14
# rows, columns = df25.shape
# print(f"df25 has Rows: {rows}, Columns: {columns}") df25 has Rows: 6676, Columns: 14

# col_names = df19.columns
# print(col_names)
# col_names = df20.columns
# print(col_names)
# col_names = df21.columns
# print(col_names)
# col_names = df22.columns
# print(col_names)
# col_names = df23.columns
# print(col_names)
# col_names = df24.columns
# print(col_names)
# col_names = df25.columns
# print(col_names)

#After checking, the columns are the same for all datasets

Train_disruption = pd.concat([df19, df20, df21, df22, df23, df24, df25])
col_names = Train_disruption.columns
print(col_names)

rows, columns = Train_disruption.shape
print(f"train_disruption has Rows: {rows}, Columns: {columns}") #Rows: 38571, Columns: 14
# Out:
# Index(['rdt_id', 'ns_lines', 'rdt_lines', 'rdt_lines_id', 'rdt_station_names',
#        'rdt_station_codes', 'cause_nl', 'cause_en', 'statistical_cause_nl',
#        'statistical_cause_en', 'cause_group', 'start_time', 'end_time',
#        'duration_minutes'],
#       dtype='str')
# train_disruption has Rows: 38571, Columns: 14

# %% [markdown]
# ## Data Preparation: Services

# %%
# For train disruptions Dataset Checking if all the column names are the same, to Concatenate them together

df19 = pd.read_csv("Datasets/disruptions-2019.csv")
df20 = pd.read_csv("Datasets/disruptions-2020.csv")
df21 = pd.read_csv("Datasets/disruptions-2021.csv")
df22 = pd.read_csv("Datasets/disruptions-2022.csv")
df23 = pd.read_csv("Datasets/disruptions-2023.csv")
df24 = pd.read_csv("Datasets/disruptions-2024.csv")
df25 = pd.read_csv("Datasets/disruptions-2025.csv")

# rows, columns = df19.shape
# print(f"df19 has Rows: {rows}, Columns: {columns}") #df19 has Rows: 5940, Columns: 14
# rows, columns = df20.shape
# print(f"df20 has Rows: {rows}, Columns: {columns}") #df20 has Rows: 4450, Columns: 14
# rows, columns = df21.shape
# print(f"df21 has Rows: {rows}, Columns: {columns}") #df21 has Rows: 4874, Columns: 14
# rows, columns = df22.shape
# print(f"df22 has Rows: {rows}, Columns: {columns}") #df22 has Rows: 5499, Columns: 14
# rows, columns = df23.shape
# print(f"df23 has Rows: {rows}, Columns: {columns}") #df23 has Rows: 5168, Columns: 14
# rows, columns = df24.shape
# print(f"df24 has Rows: {rows}, Columns: {columns}") #df24 has Rows: 5964, Columns: 14
# rows, columns = df25.shape
# print(f"df25 has Rows: {rows}, Columns: {columns}") #df25 has Rows: 6676, Columns: 14

# col_names = df19.columns
# print(col_names)
# col_names = df20.columns
# print(col_names)
# col_names = df21.columns
# print(col_names)
# col_names = df22.columns
# print(col_names)
# col_names = df23.columns
# print(col_names)
# col_names = df24.columns
# print(col_names)
# col_names = df25.columns
# print(col_names)

#After checking, the columns are the same for all datasets

Train_disruption = pd.concat([df19, df20, df21, df22, df23, df24, df25])
col_names = Train_disruption.columns
print(col_names)

rows, columns = Train_disruption.shape
print(f"train_disruption has Rows: {rows}, Columns: {columns}") #Rows: 38571, Columns: 14

# %% [markdown]
# ## Data Preparation: Weather

# %%
# For train services Dataset Checking if all the column names are the same, to Concatenate them together

dfs19 = pd.read_csv("Datasets/services-2019.csv")
dfs20 = pd.read_csv("Datasets/services-2020.csv")
dfs21 = pd.read_csv("Datasets/services-2021.csv")
dfs22 = pd.read_csv("Datasets/services-2022.csv")
dfs23 = pd.read_csv("Datasets/services-2023.csv")
dfs24 = pd.read_csv("Datasets/services-2024.csv")
dfs25 = pd.read_csv("Datasets/services-2025.csv")

rows, columns = dfs19.shape
print(f"dfs19 has Rows: {rows}, Columns: {columns}") #df19 has Rows: 5940, Columns: 14
rows, columns = dfs20.shape
print(f"dfs20 has Rows: {rows}, Columns: {columns}") #df20 has Rows: 4450, Columns: 14
rows, columns = dfs21.shape
print(f"dfs21 has Rows: {rows}, Columns: {columns}") #df21 has Rows: 4874, Columns: 14
rows, columns = dfs22.shape
print(f"dfs22 has Rows: {rows}, Columns: {columns}") #df22 has Rows: 5499, Columns: 14
rows, columns = dfs23.shape
print(f"dfs23 has Rows: {rows}, Columns: {columns}") #df23 has Rows: 5168, Columns: 14
rows, columns = dfs24.shape
print(f"dfs24 has Rows: {rows}, Columns: {columns}") #df24 has Rows: 5964, Columns: 14
rows, columns = dfs25.shape
print(f"dfs25 has Rows: {rows}, Columns: {columns}") #df25 has Rows: 6676, Columns: 14

col_names = dfs19.columns
print(col_names)
col_names = dfs20.columns
print(col_names)
col_names = dfs21.columns
print(col_names)
col_names = dfs22.columns
print(col_names)
col_names = dfs23.columns
print(col_names)
col_names = dfs24.columns
print(col_names)
col_names = dfs25.columns
print(col_names)

#After checking, the columns are the same for all datasets

# Train_disruption = pd.concat([df19, df20, df21, df22, df23, df24, df25])
# col_names = Train_disruption.columns
# print(col_names)

# rows, columns = Train_disruption.shape
# print(f"train_disruption has Rows: {rows}, Columns: {columns}") #Rows: 38571, Columns: 14
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 6
#       4 dfs20 = pd.read_csv("Datasets/services-2020.csv")
#       5 dfs21 = pd.read_csv("Datasets/services-2021.csv")
# ----> 6 dfs22 = pd.read_csv("Datasets/services-2022.csv")
#       7 dfs23 = pd.read_csv("Datasets/services-2023.csv")
#       8 dfs24 = pd.read_csv("Datasets/services-2024.csv")
#
# ...
